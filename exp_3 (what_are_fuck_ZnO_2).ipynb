# %%
import neuro_lib    # Импорт своей библиотеки для работы с Neuro обработкой файлов

file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_2\0-2020-11_26_23-57-49.txt"

param_str = [3.3, 68000] # Параметры структуры: V(В) пит., R(Ом) доп.

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')
print (param_str)

import numpy as np
import pandas as pd

data_1 = pd.read_csv(file, header=None, sep = "\t")
print (data_1, '\n')
# Out:
# [3.3, 68000]
#            0         1
# 0          6  0.023000
# 1        506  0.023000
# 2       1007  0.022875
# 3       1507  0.022875
# 4       2007  0.022875
# ...      ...       ...
# 999   209243  0.044250
# 1000  209743  0.044500
# 1001  210244  0.044375
# 1002  210744  0.044375
# 1003  211244  0.044500
#
# [1004 rows x 2 columns]

# %%
file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_2\1-2020-11_27_00-01-21.txt"

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')

data_2 = pd.read_csv(file, header=None, sep = "\t")
print (data_2, '\n')
# Out:
#            0         1
# 0          5  0.044375
# 1        505  0.044125
# 2       1005  0.044500
# 3       1506  0.044625
# 4       2006  0.044250
# ...      ...       ...
# 2444  233345  0.062875
# 2445  233845  0.062875
# 2446  234345  0.062875
# 2447  234845  0.062875
# 2448  235345  0.062500
#
# [2449 rows x 2 columns]

# %%
file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_2\2-2020-11_27_00-05-17.txt"

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')

data_3 = pd.read_csv(file, header=None, sep = "\t")
print (data_3, '\n')
# Out:
#            0         1
# 0          5  0.062875
# 1        505  0.062625
# 2       1005  0.062750
# 3       1505  0.062625
# 4       2005  0.062625
# ...      ...       ...
# 1541  218158  0.101750
# 1542  218658  0.102375
# 1543  219158  0.102125
# 1544  219658  0.102125
# 1545  220159  0.101875
#
# [1546 rows x 2 columns]

# %%
file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_2\3-2020-11_27_00-08-57.txt"

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')

data_4 = pd.read_csv(file, header=None, sep = "\t")
print (data_4, '\n')
# Out:
#            0         1
# 0          6  0.101875
# 1        506  0.102000
# 2       1007  0.102000
# 3       1507  0.102000
# 4       2008  0.101875
# ...      ...       ...
# 2639  236328  0.166750
# 2640  236828  0.167125
# 2641  237328  0.166875
# 2642  237829  0.166750
# 2643  238329  0.166875
#
# [2644 rows x 2 columns]

# %%
file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_2\4-2020-11_27_00-12-56.txt"

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')

data_5 = pd.read_csv(file, header=None, sep = "\t")
print (data_5, '\n')
# Out:
#            0         1
# 0          6  0.166750
# 1        506  0.166625
# 2       1007  0.166500
# 3       1508  0.166750
# 4       2008  0.166500
# ...      ...       ...
# 4100  260180  0.256375
# 4101  260681  0.256500
# 4102  261182  0.256500
# 4103  261682  0.256500
# 4104  262182  0.255750
#
# [4105 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

x_1 = data_1[0]/1000
y_1 = data_1[1] - 0.02

x_2 = data_2[0]/1000
y_2 = data_2[1] - 0.02

x_3 = data_3[0]/1000
y_3 = data_3[1] - 0.02

x_4 = data_4[0]/1000
y_4 = data_4[1] - 0.05

x_5 = data_5[0]/1000
y_5 = data_5[1] - 0.09

plt.rcParams['figure.figsize'] = (20, 10)  # Размер картинок
plt.title("Time dependence")

plt.plot()
plt.scatter(x_1, y_1, s=2, label = '100 - 200')
plt.scatter(x_2, y_2, s=2, label = '100 - 1000')
plt.scatter(x_3, y_3, s=2, label = '300 - 300')
plt.scatter(x_4, y_4, s=2, label = '600 - 600')
plt.scatter(x_5, y_5, s=2, label = '1000 - 1000')
#plt.yscale('log')                    #логорифмический масштаб оси Y
plt.legend()
plt.xlabel("Time (sec)")
plt.ylabel("Signal (V)")
#plt.axis([100, 112, 0, 0.125])

plt.show()

# %%
import matplotlib.pyplot as plt

x_1 = data_1[0]/1000
y_1 = 1/((param_str[0] - data_1[1])*param_str[1]/data_1[1])

x_2 = data_2[0]/1000
y_2 =  1/((param_str[0] - data_2[1])*param_str[1]/data_2[1])

x_3 = data_3[0]/1000
y_3 =  1/((param_str[0] - data_3[1])*param_str[1]/data_3[1])

x_4 = data_4[0]/1000
y_4 =  1/((param_str[0] - data_4[1])*param_str[1]/data_4[1])

x_5 = data_5[0]/1000
y_5 =  1/((param_str[0] - data_5[1])*param_str[1]/data_5[1])

plt.rcParams['figure.figsize'] = (20, 10)  # Размер картинок
plt.title("Time dependence")

plt.plot()
plt.scatter(x_1, y_1, s=2, label = '100 - 200')
plt.scatter(x_2, y_2, s=2, label = '100 - 1000')
plt.scatter(x_3, y_3, s=2, label = '300 - 300')
plt.scatter(x_4, y_4, s=2, label = '600 - 600')
plt.scatter(x_5, y_5, s=2, label = '1000 - 1000')
#plt.yscale('log')                    #логорифмический масштаб оси Y
plt.legend()
plt.xlabel("Time (sec)")
plt.ylabel("Signal (S)")
plt.axis([100, 112, 0, 0.0000011])

plt.show()
