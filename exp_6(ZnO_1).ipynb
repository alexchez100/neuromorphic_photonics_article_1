# %%
import neuro_lib    # Импорт своей библиотеки для работы с Neuro обработкой файлов

file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_1\2020-11_25_11-35-23.txt"

param_str = [3.3, 68000] # Параметры структуры: V(В) пит., R(Ом) доп.

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')
print (param_str)

import numpy as np
import pandas as pd

data_2_min = pd.read_csv(file, header=None, sep = "\t")
print (data_2_min, '\n')
# Out:
# [3.3, 68000]
#                0         1
# 0             11  0.325125
# 1            211  0.324750
# 2            412  0.324875
# 3            612  0.325000
# 4            812  0.325375
# ...          ...       ...
# 865287  43519853  0.336125
# 865288  43520053  0.335750
# 865289  43520253  0.335625
# 865290  43520454  0.335500
# 865291  43520654  0.335750
#
# [865292 rows x 2 columns]

# %%
import neuro_lib    # Импорт своей библиотеки для работы с Neuro обработкой файлов

file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_1\2020-11_26_01-48-53.txt"

param_str = [3.3, 68000] # Параметры структуры: V(В) пит., R(Ом) доп.

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')
print (param_str)

import numpy as np
import pandas as pd

data_05_min = pd.read_csv(file, header=None, sep = "\t")
print (data_05_min, '\n')
# Out:
# [3.3, 68000]
#                0         1
# 0              5  0.287125
# 1            205  0.286875
# 2            405  0.286500
# 3            605  0.286875
# 4            805  0.287125
# ...          ...       ...
# 863323  43429657  0.273500
# 863324  43429858  0.273500
# 863325  43430058  0.273625
# 863326  43430258  0.273625
# 863327  43430458  0.273750
#
# [863328 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

x_1 = data_2_min[0]/1000
y_1 = data_2_min[1]

x_2 = data_05_min[0]/1000
y_2 = data_05_min[1]

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок
plt.title("Time dependence")

plt.plot()
plt.scatter(x_1, y_1, s=0.2, label = '120 sec')
plt.scatter(x_2, y_2, s=0.2, label = '30 sec')
#plt.yscale('log')                    #логорифмический масштаб оси Y
plt.legend()
plt.xlabel("Time (sec)")
plt.ylabel("Signal (V)")
#plt.axis([0, 40, 0, 0.01])

plt.show()

# %%
import matplotlib.pyplot as plt

x_1 = data_2_min[0]/1000
y_1 = 1/((param_str[0] - data_2_min[1])*param_str[1]/data_2_min[1])

x_2 = data_05_min[0]/1000
y_2 = 1/((param_str[0] - data_05_min[1])*param_str[1]/data_05_min[1])

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок
plt.title("Time dependence")

plt.plot()
plt.scatter(x_1, y_1, s=0.2, label = '120 sec')
plt.scatter(x_2, y_2, s=0.2, label = '30 sec')
#plt.yscale('log')                    #логорифмический масштаб оси Y
plt.legend()
plt.xlabel("Time (sec)")
plt.ylabel("Conductivity (S)")
plt.axis([-500, 45000, 0, 0.000025])

plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок
plt.title("Time dependence")

plt.plot()
plt.scatter(x_1, y_1, s=0.2, label = '120 sec')
plt.scatter(x_2, y_2, s=0.2, label = '30 sec')
#plt.yscale('log')                    #логорифмический масштаб оси Y
plt.legend()
plt.xlabel("Time (sec)")
plt.ylabel("Conductivity (S)")
plt.axis([-500, 2000, 0, 0.000025])

plt.show()
