# %% [markdown]
# # 2-ой График

# %%
import neuro_lib    # Импорт своей библиотеки для работы с Neuro обработкой файлов

file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_1\2020-11_19_21-02-28.txt"

param_str = [3.3, 68000] # Параметры структуры: V(В) пит., R(Ом) доп.

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')
print (param_str)

import numpy as np
import pandas as pd

data = pd.read_csv(file, header=None, sep = "\t")
print (data, '\n')
# Out:
# [3.3, 68000]
#                0         1
# 0              5  0.100500
# 1           1005  0.100000
# 2           2006  0.100125
# 3           3006  0.100375
# 4           4006  0.100125
# ...          ...       ...
# 848863  71972790  0.620000
# 848864  71973790  0.621000
# 848865  71974790  0.620625
# 848866  71975790  0.620375
# 848867  71976791  0.620375
#
# [848868 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок

x = data[0]/1000
y = data[1]

fig, ax = plt.subplots()
ax.set_facecolor('w') # установка фона графика

ax.plot(x, y, linewidth = 0.5, label="ZnO_1 (0.00002 - 0.00003)", color='r')
ax.legend()
ax.set_xlabel("Time (sec)")
ax.set_ylabel("Signal (V)")
plt.title("Time dependence")
#ax.axis([-5000, 230000, 1.25, 2])
plt.show()

# %%
import neuro_lib_2
res_1 = neuro_lib_2.on_off_impulse(file)
print (res_1.head().to_string())

x = res_1['N'].drop(1)
y_on = res_1['on_end_t'].drop(1) - res_1['on_start_t'].drop(1)
y_off = res_1['off_end_t'].drop(1) - res_1['off_start_t'].drop(1)

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок

fig, ax1 = plt.subplots()
ax1.set_facecolor('w') # установка фона графика
ax2 = ax1.twinx() # позволяет вывести 2 графика на 1

curve1 = ax1.scatter(x, y_on, s=4, label="on", color='r')
curve2 = ax2.scatter(x, y_off, s=4, label="off", color='b')
curves = [curve1, curve2]
#ax1.legend(curves, [curve.get_label() for curve in curves], facecolor="yellow") # ??? отображение легенды

ax1.set_xlabel("Pulse number (N)")
ax1.set_ylabel("Delay_on t (sec)", color = 'red')
ax2.set_ylabel("Delay_off t (sec)", color = 'blue')
plt.title("Duration on / off from pulse number")
#ax1.axis([0, 50, 0, 15])

plt.grid(False) # отключение сетки
plt.show()
# Out:
#    N on_start_t on_start_V on_end_t on_end_V off_start_t off_start_V off_end_t off_end_V
# 0  0        NaN        NaN      NaN      NaN         NaN         NaN   100.035       0.1
# 1  1    101.051     0.1245   325.56  2.21513     325.616     2.20012   578.983     1.901
# 2  2    579.049    1.93625   616.91  2.21462     616.966     2.19775   957.273   1.90138
# 3  3    957.341      1.952  987.455    2.215     987.511     2.19975   1396.23   1.90088
# 4  4     1396.3     1.9515  1422.94  2.21488     1422.99       2.199   1875.72   1.90162

# %%
x__2 = res_1['N'].drop(1)
y__2 = y_on+y_off

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок
plt.title("Duration on + off from pulse number")

plt.plot()
plt.scatter(x__2, 1/y__2, s=4)
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (Hz)")
plt.axis([0, 50, 0, 0.005])

plt.show()

# %% [markdown]
# # 4-ый График

# %%
import neuro_lib    # Импорт своей библиотеки для работы с Neuro обработкой файлов

file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_1\2020-11_20_17-39-45.txt"

param_str = [3.3, 68000] # Параметры структуры: V(В) пит., R(Ом) доп.

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')
print (param_str)

import numpy as np
import pandas as pd

data = pd.read_csv(file, header=None, sep = "\t")
print (data, '\n')
# Out:
# [3.3, 68000]
#                 0         1
# 0               5  0.585750
# 1            1005  0.585250
# 2            2005  0.585375
# 3            3006  0.585375
# 4            4006  0.585500
# ...           ...       ...
# 1675110  84083979  2.122500
# 1675111  84084029  2.123625
# 1675112  84084079  2.123750
# 1675113  84084129  2.124250
# 1675114  84084179  2.123875
#
# [1675115 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок

x = data[0]/1000
y = data[1]

fig, ax = plt.subplots()
ax.set_facecolor('w') # установка фона графика

ax.plot(x, y, linewidth = 0.5, label="ZnO_1 (0.00002 - 0.00004)", color='r')
ax.legend()
ax.set_xlabel("Time (sec)")
ax.set_ylabel("Signal (V)")
plt.title("Time dependence")
#ax.axis([-5000, 230000, 1.25, 2])
plt.show()

# %%
import neuro_lib_2
res_1 = neuro_lib_2.on_off_impulse(file)
print (res_1.head().to_string())

x = res_1['N'].drop(1)
y_on = res_1['on_end_t'].drop(1) - res_1['on_start_t'].drop(1)
y_off = res_1['off_end_t'].drop(1) - res_1['off_start_t'].drop(1)

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок

fig, ax1 = plt.subplots()
ax1.set_facecolor('w') # установка фона графика
ax2 = ax1.twinx() # позволяет вывести 2 графика на 1

curve1 = ax1.scatter(x, y_on, s=4, label="on", color='r')
curve2 = ax2.scatter(x, y_off, s=4, label="off", color='b')
curves = [curve1, curve2]
#ax1.legend(curves, [curve.get_label() for curve in curves], facecolor="yellow") # ??? отображение легенды

ax1.set_xlabel("Pulse number (N)")
ax1.set_ylabel("Delay_on t (sec)", color = 'red')
ax2.set_ylabel("Delay_off t (sec)", color = 'blue')
plt.title("Duration on / off from pulse number")
#ax1.axis([0, 50, 0, 15])

plt.grid(False) # отключение сетки
plt.show()
# Out:
#    N on_start_t on_start_V on_end_t on_end_V off_start_t off_start_V off_end_t off_end_V
# 0  0        NaN        NaN      NaN      NaN         NaN         NaN   100.034  0.584625
# 1  1     101.05    0.66175  333.871    2.413     333.928     2.40075   1381.27   1.90162
# 2  2    1381.34    1.95612  1457.61    2.413     1457.66     2.40225   2856.94   1.90125
# 3  3    2857.01    1.95875  2923.68  2.41312     2923.74     2.40112   4480.42   1.90138
# 4  4    4480.49    1.96125  4543.54  2.41375      4543.6     2.40137   6212.47   1.90162

# %%
x__4 = res_1['N'].drop(1)
y__4 = y_on+y_off

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок
plt.title("Duration on + off from pulse number")

plt.plot()
plt.scatter(x__4, 1/y__4, s=4)
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (Hz)")
plt.axis([0, 50, 0, 0.001])

plt.show()

# %% [markdown]
# # 1-ый График

# %%
import neuro_lib    # Импорт своей библиотеки для работы с Neuro обработкой файлов

file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_1\2020-11_22_16-20-06.txt"

param_str = [3.3, 68000] # Параметры структуры: V(В) пит., R(Ом) доп.

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')
print (param_str)

import numpy as np
import pandas as pd

data = pd.read_csv(file, header=None, sep = "\t")
print (data, '\n')
# Out:
# [3.3, 68000]
#                0         1
# 0              6  0.250625
# 1           1006  0.250625
# 2           2007  0.249875
# 3           3008  0.250000
# 4           4008  0.250250
# ...          ...       ...
# 354806  92170720  0.259750
# 354807  92171721  0.259875
# 354808  92172721  0.260000
# 354809  92173721  0.260375
# 354810  92174722  0.260375
#
# [354811 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок

x = data[0]/1000
y = data[1]

fig, ax = plt.subplots()
ax.set_facecolor('w') # установка фона графика

ax.plot(x, y, linewidth = 0.5, label="ZnO_1 (0.00002 - 0.000025)", color='r')
ax.legend()
ax.set_xlabel("Time (sec)")
ax.set_ylabel("Signal (V)")
plt.title("Time dependence")
ax.axis([-500, 20000, 1.25, 2.5])
plt.show()

# %%
import neuro_lib_2
res_1 = neuro_lib_2.on_off_impulse(file)
print (res_1.head().to_string())

x = res_1['N'].drop(1)
y_on = res_1['on_end_t'].drop(1) - res_1['on_start_t'].drop(1)
y_off = res_1['off_end_t'].drop(1) - res_1['off_start_t'].drop(1)

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок

fig, ax1 = plt.subplots()
ax1.set_facecolor('w') # установка фона графика
ax2 = ax1.twinx() # позволяет вывести 2 графика на 1

curve1 = ax1.scatter(x, y_on, s=4, label="on", color='r')
curve2 = ax2.scatter(x, y_off, s=4, label="off", color='b')
curves = [curve1, curve2]
#ax1.legend(curves, [curve.get_label() for curve in curves], facecolor="yellow") # ??? отображение легенды

ax1.set_xlabel("Pulse number (N)")
ax1.set_ylabel("Delay_on t (sec)", color = 'red')
ax2.set_ylabel("Delay_off t (sec)", color = 'blue')
plt.title("Duration on / off from pulse number")
#ax1.axis([0, 50, 0, 15])

plt.grid(False) # отключение сетки
plt.show()
# Out:
#    N on_start_t on_start_V on_end_t on_end_V off_start_t off_start_V off_end_t off_end_V
# 0  0        NaN        NaN      NaN      NaN         NaN         NaN   100.034   0.25025
# 1  1    101.051      0.296  241.975    2.078      242.03     2.06237    327.51   1.90162
# 2  2    327.576    1.95063  341.906  2.07863     341.961     2.06175   451.412   1.90162
# 3  3    451.481    1.94925   463.02    2.078     463.076     2.05912   593.315    1.9015
# 4  4    593.382      1.945  603.508  2.07812     603.563     2.06137   750.684    1.9015

# %%
x__1 = res_1['N'].drop(1)
y__1 = y_on+y_off

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок
plt.title("Duration on + off from pulse number")

plt.plot()
plt.scatter(x__1, 1/y__1, s=4)
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (Hz)")
plt.axis([0, 50, 0, 0.013])

plt.show()

# %% [markdown]
# # 3-ий График

# %%
import neuro_lib    # Импорт своей библиотеки для работы с Neuro обработкой файлов

file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_1\2020-11_24_00-06-28.txt"

param_str = [3.3, 68000] # Параметры структуры: V(В) пит., R(Ом) доп.

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')
print (param_str)

import numpy as np
import pandas as pd

data = pd.read_csv(file, header=None, sep = "\t")
print (data, '\n')
# Out:
# [3.3, 68000]
#                 0         1
# 0               5  0.185625
# 1            1005  0.185500
# 2            2006  0.185625
# 3            3007  0.185500
# 4            4007  0.185625
# ...           ...       ...
# 1354508  68036768  2.090875
# 1354509  68036818  2.089000
# 1354510  68036868  2.091125
# 1354511  68036918  2.090875
# 1354512  68036968  2.091750
#
# [1354513 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок

x = data[0]/1000
y = data[1]

fig, ax = plt.subplots()
ax.set_facecolor('w') # установка фона графика

ax.plot(x, y, linewidth = 0.5, label="ZnO_1 (0.00002 - 0.000035)", color='r')
ax.legend()
ax.set_xlabel("Time (sec)")
ax.set_ylabel("Signal (V)")
plt.title("Time dependence")
#ax.axis([-500, 20000, 1.25, 2.5])
plt.show()

# %%
import neuro_lib_2
res_1 = neuro_lib_2.on_off_impulse(file)
print (res_1.head().to_string())

x = res_1['N'].drop(1)
y_on = res_1['on_end_t'].drop(1) - res_1['on_start_t'].drop(1)
y_off = res_1['off_end_t'].drop(1) - res_1['off_start_t'].drop(1)

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок

fig, ax1 = plt.subplots()
ax1.set_facecolor('w') # установка фона графика
ax2 = ax1.twinx() # позволяет вывести 2 графика на 1

curve1 = ax1.scatter(x, y_on, s=4, label="on", color='r')
curve2 = ax2.scatter(x, y_off, s=4, label="off", color='b')
curves = [curve1, curve2]
#ax1.legend(curves, [curve.get_label() for curve in curves], facecolor="yellow") # ??? отображение легенды

ax1.set_xlabel("Pulse number (N)")
ax1.set_ylabel("Delay_on t (sec)", color = 'red')
ax2.set_ylabel("Delay_off t (sec)", color = 'blue')
plt.title("Duration on / off from pulse number")
#ax1.axis([0, 50, 0, 15])

plt.grid(False) # отключение сетки
plt.show()
# Out:
#    N on_start_t on_start_V on_end_t on_end_V off_start_t off_start_V off_end_t off_end_V
# 0  0        NaN        NaN      NaN      NaN         NaN         NaN   100.037  0.185125
# 1  1    101.053   0.231625  374.154   2.3245     374.209     2.31263   953.203   1.90112
# 2  2     953.27    1.95463  1016.51    2.324     1016.57     2.31087   1826.03    1.9015
# 3  3     1826.1    1.95637  1878.06  2.32388     1878.11     2.31013   2838.62   1.90162
# 4  4    2838.68      1.951  2886.23  2.32437     2886.28       2.312   3986.95   1.90138

# %%
x__3 = res_1['N'].drop(1)
y__3 = y_on+y_off

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок
plt.title("Duration on + off from pulse number")

plt.plot()
plt.scatter(x__3, 1/y__3, s=4)
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (Hz)")
plt.axis([0, 50, 0, 0.003])

plt.show()

# %% [markdown]
# # Итоговый график

# %%
plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок
plt.title("Dependence of the pulse frequency on the size of the conduction boundaries (log)")

plt.plot()
plt.scatter(x__1, 1/y__1, s=5, label = '0.00002 - 0.000025')
plt.scatter(x__2, 1/y__2, s=5, label = '0.00002 - 0.00003')
plt.scatter(x__3, 1/y__3, s=5, label = '0.00002 - 0.000035')
plt.scatter(x__4, 1/y__4, s=5, label = '0.00002 - 0.00004')
plt.yscale('log')                    #логорифмический масштаб оси Y
plt.legend()
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (Hz)")
#plt.axis([0, 40, 0, ])

plt.show()

# %%
plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок
plt.title("Dependence of the pulse frequency on the size of the conduction boundaries")

plt.plot()
plt.scatter(x__1, 1/y__1, s=5, label = '0.00002 - 0.000025')
plt.scatter(x__2, 1/y__2, s=5, label = '0.00002 - 0.00003')
plt.scatter(x__3, 1/y__3, s=5, label = '0.00002 - 0.000035')
plt.scatter(x__4, 1/y__4, s=5, label = '0.00002 - 0.00004')
#plt.yscale('log')                    #логорифмический масштаб оси Y
plt.legend()
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (Hz)")
plt.axis([0, 40, 0, 0.01])

plt.show()
