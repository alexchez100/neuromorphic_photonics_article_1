# %% [markdown]
# # 1 график (нижняя граница)

# %%
import neuro_lib    # Импорт своей библиотеки для работы с Neuro обработкой файлов

file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_1\2020-11_09_19-49-43.txt"

param_str = [3.3, 68000] # Параметры структуры: V(В) пит., R(Ом) доп.

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')
print (param_str)
# Out:
# [3.3, 68000]

# %%
import numpy as np
import pandas as pd

data = pd.read_csv(file, header=None, sep = "\t")
print (data, '\n')
#print (data[0], '\n')
# Out:
#                  0         1
# 0                5  0.050125
# 1             1006  0.050500
# 2             2007  0.050250
# 3             3008  0.050500
# 4             4008  0.050250
# ...            ...       ...
# 4492207  307412928  0.145875
# 4492208  307413928  0.145875
# 4492209  307414929  0.146000
# 4492210  307415929  0.146000
# 4492211  307416930  0.145375
#
# [4492212 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок

x = data[0]/1000
y = data[1]

fig, ax = plt.subplots()
ax.set_facecolor('w') # установка фона графика

ax.plot(x, y, linewidth = 0.5, label="ZnO_1-1", color='r')
ax.legend()
ax.set_xlabel("Time (sec)")
ax.set_ylabel("Signal (V)")
plt.title("Time dependence")
#ax.axis([-5000, 230000, 1.25, 2])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import neuro_lib_2
file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_1\2020-11_09_19-49-43.txt"
res_1 = neuro_lib_2.on_off_impulse(file)
print (res_1.head().to_string())
# Out:
#    N on_start_t on_start_V on_end_t on_end_V off_start_t off_start_V off_end_t off_end_V
# 0  0        NaN        NaN      NaN      NaN         NaN         NaN   100.053  0.050625
# 1  1     101.07   0.071375  193.617  1.90712     193.674     1.88525     687.5   1.33563
# 2  2    687.568    1.40488  707.335  1.90738     707.395     1.88025   1489.45   1.33563
# 3  3    1489.51    1.40475   1505.6  1.90762     1505.66       1.886   2475.62    1.3355
# 4  4    2475.68    1.40225  2490.36  1.90738     2490.42      1.8895   3606.83   1.33563

# %%
x = res_1['N'].drop(1)
y_on = res_1['on_end_t'].drop(1) - res_1['on_start_t'].drop(1)
y_off = res_1['off_end_t'].drop(1) - res_1['off_start_t'].drop(1)

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок

fig, ax1 = plt.subplots()
ax1.set_facecolor('w') # установка фона графика
ax2 = ax1.twinx() # позволяет вывести 2 графика на 1

curve1 = ax1.scatter(x, y_on, s=4, label="on", color='r')
curve2 = ax2.scatter(x, y_off, s=4, label="off", color='b')
curves = [curve1, curve2]
#ax1.legend(curves, [curve.get_label() for curve in curves], facecolor="yellow") # ??? отображение легенды

ax1.set_xlabel("Pulse number (N)")
ax1.set_ylabel("Delay_on t (sec)", color = 'red')
ax2.set_ylabel("Delay_off t (sec)", color = 'blue')
plt.title("Duration on / off from pulse number")
#ax1.axis([0, 50, 0, 15])

plt.grid(False) # отключение сетки
plt.show()

# %%
x__1 = res_1['N'].drop(1)
y__1 = y_on+y_off

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок
plt.title("Duration on + off from pulse number")

plt.subplot(1, 2, 1)
plt.scatter(x__1, y__1, s=4)
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (sec)")

plt.subplot(1, 2, 2)
plt.scatter(x__1, 1/y__1, s=4)
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (Hz)")
plt.axis([0, 100, 0, 0.00175])

plt.show()

# %% [markdown]
# # 2 График

# %%
import neuro_lib    # Импорт своей библиотеки для работы с Neuro обработкой файлов

file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_1\2020-11_13_16-50-58.txt"

param_str = [3.3, 68000] # Параметры структуры: V(В) пит., R(Ом) доп.

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')
print (param_str)

import numpy as np
import pandas as pd

data = pd.read_csv(file, header=None, sep = "\t")
print (data, '\n')
# Out:
# [3.3, 68000]
#                 0         1
# 0               6  0.097625
# 1            1007  0.097625
# 2            2007  0.097250
# 3            3008  0.097625
# 4            4008  0.097500
# ...           ...       ...
# 626914  113644375  0.154125
# 626915  113645375  0.153875
# 626916  113646375  0.153625
# 626917  113647375  0.153750
# 626918  113648375  0.154000
#
# [626919 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок

x = data[0]/1000
y = data[1]

fig, ax = plt.subplots()
ax.set_facecolor('w') # установка фона графика

ax.plot(x, y, linewidth = 0.5, label="ZnO_1-2", color='r')
ax.legend()
ax.set_xlabel("Time (sec)")
ax.set_ylabel("Signal (V)")
plt.title("Time dependence")
ax.axis([-1000, 40000, 1.5, 2.51])
plt.show()

# %%
import neuro_lib_2
res_1 = neuro_lib_2.on_off_impulse(file)
print (res_1.head().to_string())

x = res_1['N'].drop(1)
y_on = res_1['on_end_t'].drop(1) - res_1['on_start_t'].drop(1)
y_off = res_1['off_end_t'].drop(1) - res_1['off_start_t'].drop(1)

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок

fig, ax1 = plt.subplots()
ax1.set_facecolor('w') # установка фона графика
ax2 = ax1.twinx() # позволяет вывести 2 графика на 1

curve1 = ax1.scatter(x, y_on, s=4, label="on", color='r')
curve2 = ax2.scatter(x, y_off, s=4, label="off", color='b')
curves = [curve1, curve2]
#ax1.legend(curves, [curve.get_label() for curve in curves], facecolor="yellow") # ??? отображение легенды

ax1.set_xlabel("Pulse number (N)")
ax1.set_ylabel("Delay_on t (sec)", color = 'red')
ax2.set_ylabel("Delay_off t (sec)", color = 'blue')
plt.title("Duration on / off from pulse number")
#ax1.axis([0, 50, 0, 15])

plt.grid(False) # отключение сетки
plt.show()
# Out:
#    N on_start_t on_start_V on_end_t on_end_V off_start_t off_start_V off_end_t off_end_V
# 0  0        NaN        NaN      NaN      NaN         NaN         NaN   100.039  0.097625
# 1  1    101.054   0.134125  365.449    2.413     365.505     2.39288   463.751   2.21425
# 2  2    463.817    2.25738   494.16    2.413     494.216      2.4005   610.389   2.21437
# 3  3    610.455    2.25475  634.929  2.41337     634.986      2.3995   765.167   2.21413
# 4  4    765.232    2.25963  786.613  2.41325     786.669     2.40187   926.962   2.21437

# %%
x__2 = res_1['N'].drop(1)
y__2 = y_on+y_off

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок
plt.title("Duration on + off from pulse number")

plt.subplot(1, 2, 1)
plt.scatter(x__2, y__2, s=4)
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (sec)")

plt.subplot(1, 2, 2)
plt.scatter(x__2, 1/y__2, s=4)
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (Hz)")
plt.axis([0, 100, 0, 0.009])

plt.show()

# %% [markdown]
# # График 3

# %%
import neuro_lib    # Импорт своей библиотеки для работы с Neuro обработкой файлов

file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_1\2020-11_15_13-06-59.txt"

param_str = [3.3, 68000] # Параметры структуры: V(В) пит., R(Ом) доп.

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')
print (param_str)

import numpy as np
import pandas as pd

data = pd.read_csv(file, header=None, sep = "\t")
print (data, '\n')
# Out:
# [3.3, 68000]
#                0         1
# 0              6  0.081750
# 1           1007  0.081375
# 2           2007  0.081750
# 3           3007  0.081625
# 4           4007  0.081625
# ...          ...       ...
# 271176  95775359  0.179625
# 271177  95776359  0.180125
# 271178  95777359  0.179625
# 271179  95778360  0.179750
# 271180  95779360  0.179750
#
# [271181 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок

x = data[0]/1000
y = data[1]

fig, ax = plt.subplots()
ax.set_facecolor('w') # установка фона графика

ax.plot(x, y, linewidth = 0.5, label="ZnO_1-3", color='r')
ax.legend()
ax.set_xlabel("Time (sec)")
ax.set_ylabel("Signal (V)")
plt.title("Time dependence")
ax.axis([-100, 10000, 2.3, 2.7])
plt.show()

# %%
import neuro_lib_2
res_1 = neuro_lib_2.on_off_impulse(file)
print (res_1.head().to_string())

x = res_1['N'].drop(1)
y_on = res_1['on_end_t'].drop(1) - res_1['on_start_t'].drop(1)
y_off = res_1['off_end_t'].drop(1) - res_1['off_start_t'].drop(1)

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок

fig, ax1 = plt.subplots()
ax1.set_facecolor('w') # установка фона графика
ax2 = ax1.twinx() # позволяет вывести 2 графика на 1

curve1 = ax1.scatter(x, y_on, s=4, label="on", color='r')
curve2 = ax2.scatter(x, y_off, s=4, label="off", color='b')
curves = [curve1, curve2]
#ax1.legend(curves, [curve.get_label() for curve in curves], facecolor="yellow") # ??? отображение легенды

ax1.set_xlabel("Pulse number (N)")
ax1.set_ylabel("Delay_on t (sec)", color = 'red')
ax2.set_ylabel("Delay_off t (sec)", color = 'blue')
plt.title("Duration on / off from pulse number")
#ax1.axis([0, 50, 0, 15])

plt.grid(False) # отключение сетки
plt.show()
# Out:
#    N on_start_t on_start_V on_end_t on_end_V off_start_t off_start_V off_end_t off_end_V
# 0  0        NaN        NaN      NaN      NaN         NaN         NaN   100.019  0.081375
# 1  1    101.037    0.11225  672.574  2.65088     672.629     2.63975   715.306   2.54975
# 2  2    715.371    2.57613  756.103   2.6505     756.158     2.64038    800.65   2.54925
# 3  3    800.717    2.57925  833.176   2.6505     833.232     2.64288   881.796   2.54988
# 4  4    881.862    2.57812   911.27  2.65112     911.327     2.63888   962.646   2.54925

# %%
x__3 = res_1['N'].drop(1)
y__3 = y_on+y_off

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок
plt.title("Duration on + off from pulse number")

plt.subplot(1, 2, 1)
plt.scatter(x__3, y__3, s=4)
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (sec)")

plt.subplot(1, 2, 2)
plt.scatter(x__3, 1/y__3, s=4)
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (Hz)")
plt.axis([0, 100, 0, 0.016])

plt.show()

# %% [markdown]
# # График 4

# %%
import neuro_lib    # Импорт своей библиотеки для работы с Neuro обработкой файлов

file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_1\2020-11_16_21-58-56.txt"

param_str = [3.3, 68000] # Параметры структуры: V(В) пит., R(Ом) доп.

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')
print (param_str)

import numpy as np
import pandas as pd

data = pd.read_csv(file, header=None, sep = "\t")
print (data, '\n')
# Out:
# [3.3, 68000]
#                0         1
# 0              6  0.126625
# 1           1007  0.126500
# 2           2007  0.126625
# 3           3007  0.126375
# 4           4007  0.126375
# ...          ...       ...
# 173055  65056251  0.330250
# 173056  65057251  0.330625
# 173057  65058251  0.330625
# 173058  65059251  0.330375
# 173059  65060252  0.330375
#
# [173060 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок

x = data[0]/1000
y = data[1]

fig, ax = plt.subplots()
ax.set_facecolor('w') # установка фона графика

ax.plot(x, y, linewidth = 0.5, label="ZnO_1-4", color='r')
ax.legend()
ax.set_xlabel("Time (sec)")
ax.set_ylabel("Signal (V)")
plt.title("Time dependence")
ax.axis([-100, 8000, 2.6, 2.85])
plt.show()

# %%
import neuro_lib_2
res_1 = neuro_lib_2.on_off_impulse(file)
print (res_1.head().to_string())

x = res_1['N'].drop(1)
y_on = res_1['on_end_t'].drop(1) - res_1['on_start_t'].drop(1)
y_off = res_1['off_end_t'].drop(1) - res_1['off_start_t'].drop(1)

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок

fig, ax1 = plt.subplots()
ax1.set_facecolor('w') # установка фона графика
ax2 = ax1.twinx() # позволяет вывести 2 графика на 1

curve1 = ax1.scatter(x, y_on, s=4, label="on", color='r')
curve2 = ax2.scatter(x, y_off, s=4, label="off", color='b')
curves = [curve1, curve2]
#ax1.legend(curves, [curve.get_label() for curve in curves], facecolor="yellow") # ??? отображение легенды

ax1.set_xlabel("Pulse number (N)")
ax1.set_ylabel("Delay_on t (sec)", color = 'red')
ax2.set_ylabel("Delay_off t (sec)", color = 'blue')
plt.title("Duration on / off from pulse number")
#ax1.axis([0, 50, 0, 15])

plt.grid(False) # отключение сетки
plt.show()
# Out:
#    N on_start_t on_start_V on_end_t on_end_V off_start_t off_start_V off_end_t off_end_V
# 0  0        NaN        NaN      NaN      NaN         NaN         NaN   100.022  0.126625
# 1  1    101.039    0.16075  1133.34  2.78762     1133.39     2.77925   1155.18   2.72688
# 2  2    1155.25    2.74538  1202.47  2.78762     1202.52     2.78087   1225.42    2.7265
# 3  3    1225.48    2.74425  1264.06  2.78788     1264.12     2.78087   1286.16   2.72675
# 4  4    1286.23    2.74975  1319.13  2.78762     1319.18     2.77925   1342.07   2.72662

# %%
x__4 = res_1['N'].drop(1)
y__4 = y_on+y_off

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок
plt.title("Duration on + off from pulse number")

plt.subplot(1, 2, 1)
plt.scatter(x__4, y__4, s=4)
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (sec)")

plt.subplot(1, 2, 2)
plt.scatter(x__4, 1/y__4, s=4)
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (Hz)")
plt.axis([0, 100, 0, 0.028])

plt.show()

# %% [markdown]
# # График 4 (повторное измерение)

# %%
import neuro_lib    # Импорт своей библиотеки для работы с Neuro обработкой файлов

file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_1\2020-11_18_01-05-50.txt"

param_str = [3.3, 68000] # Параметры структуры: V(В) пит., R(Ом) доп.

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')
print (param_str)

import numpy as np
import pandas as pd

data = pd.read_csv(file, header=None, sep = "\t")
print (data, '\n')
# Out:
# [3.3, 68000]
#                0         1
# 0              5  0.189000
# 1           1005  0.189125
# 2           2005  0.189000
# 3           3005  0.189375
# 4           4005  0.189500
# ...          ...       ...
# 219059  93170973  0.223250
# 219060  93171973  0.223375
# 219061  93172973  0.223375
# 219062  93173974  0.223250
# 219063  93174974  0.223875
#
# [219064 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок

x = data[0]/1000
y = data[1]

fig, ax = plt.subplots()
ax.set_facecolor('w') # установка фона графика

ax.plot(x, y, linewidth = 0.5, label="ZnO_1-4", color='r')
ax.legend()
ax.set_xlabel("Time (sec)")
ax.set_ylabel("Signal (V)")
plt.title("Time dependence")
ax.axis([-100, 8000, 2.6, 2.85])
plt.show()

# %%
import neuro_lib_2
res_1 = neuro_lib_2.on_off_impulse(file)
print (res_1.head().to_string())

x = res_1['N'].drop(1)
y_on = res_1['on_end_t'].drop(1) - res_1['on_start_t'].drop(1)
y_off = res_1['off_end_t'].drop(1) - res_1['off_start_t'].drop(1)

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок

fig, ax1 = plt.subplots()
ax1.set_facecolor('w') # установка фона графика
ax2 = ax1.twinx() # позволяет вывести 2 графика на 1

curve1 = ax1.scatter(x, y_on, s=4, label="on", color='r')
curve2 = ax2.scatter(x, y_off, s=4, label="off", color='b')
curves = [curve1, curve2]
#ax1.legend(curves, [curve.get_label() for curve in curves], facecolor="yellow") # ??? отображение легенды

ax1.set_xlabel("Pulse number (N)")
ax1.set_ylabel("Delay_on t (sec)", color = 'red')
ax2.set_ylabel("Delay_off t (sec)", color = 'blue')
plt.title("Duration on / off from pulse number")
#ax1.axis([0, 50, 0, 15])

plt.grid(False) # отключение сетки
plt.show()
# Out:
#    N on_start_t on_start_V on_end_t on_end_V off_start_t off_start_V off_end_t off_end_V
# 0  0        NaN        NaN      NaN      NaN         NaN         NaN   100.013   0.18875
# 1  1    101.028   0.243875  1280.58    2.788     1280.63     2.77962   1307.94     2.727
# 2  2    1308.01    2.74187   1368.1  2.78762     1368.16     2.78125   1395.72   2.72688
# 3  3    1395.79    2.74288   1447.4  2.78775     1447.45       2.779   1473.89   2.72688
# 4  4    1473.95    2.74475  1520.05  2.78762      1520.1      2.7805   1548.36   2.72688

# %%
x__5 = res_1['N'].drop(1)
y__5 = y_on+y_off

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок
plt.title("Duration on + off from pulse number")

plt.subplot(1, 2, 1)
plt.scatter(x__5, y__5, s=4)
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (sec)")

plt.subplot(1, 2, 2)
plt.scatter(x__5, 1/y__5, s=4)
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (Hz)")
plt.axis([0, 100, 0, 0.028])

plt.show()

# %% [markdown]
# # Итоговые графики

# %%
plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок
plt.title("Dependence of the pulse frequency on the choice of the conductivity boundary level")

plt.plot()
plt.scatter(x__1, 1/y__1, s=5, label = '0.00001 - 0.00002')
plt.scatter(x__2, 1/y__2, s=5, label = '0.00003 - 0.00004')
plt.scatter(x__3, 1/y__3, s=5, label = '0.00005 - 0.00006')
plt.scatter(x__5, 1/y__5, s=5, label = '0.00007 - 0.00008')
#plt.yscale('log')                    #логорифмический масштаб оси Y
plt.legend(loc = 'upper right')
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (Hz)")
plt.axis([0, 100, 0, 0.022])

plt.show()

# %%
plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок
plt.title("Dependence of the pulse frequency on the choice of the conductivity boundary level (log)")

plt.plot()
plt.scatter(x__1, 1/y__1, s=5, label = '0.00001 - 0.00002')
plt.scatter(x__2, 1/y__2, s=5, label = '0.00003 - 0.00004')
plt.scatter(x__3, 1/y__3, s=5, label = '0.00005 - 0.00006')
plt.scatter(x__5, 1/y__5, s=5, label = '0.00007 - 0.00008')
plt.yscale('log')                    #логорифмический масштаб оси Y
plt.legend(loc = 'upper right')
plt.xlabel("Pulse number (N)")
plt.ylabel("Delay_on+off t (Hz)")
#plt.axis([0, 100, 0, 0.022])

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib
mpl.rc('font',family='Times New Roman')  # выставление правильного шрифта

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок
#plt.title("Dependence of the pulse frequency on the choice of the conductivity boundary level")

plt.plot()
plt.scatter(x__1, 1/y__1, s=5, label = '10-20 $\mu$S')
plt.scatter(x__2, 1/y__2, s=5, label = '30-40 $\mu$S')
plt.scatter(x__3, 1/y__3, s=5, label = '50-60 $\mu$S')
plt.scatter(x__5, 1/y__5, s=5, label = '70-80 $\mu$S')
#plt.yscale('log')                    #логорифмический масштаб оси Y
plt.legend(loc = 'upper right')
plt.xlabel("Номер импульса (N)")
plt.ylabel("Частота адаптации (Hz)")
plt.axis([0, 100, 0, 0.022])

matplotlib.rcParams.update({'font.size': 14})
fig.tight_layout()

#plt.show()
plt.savefig('4(rus).svg')
