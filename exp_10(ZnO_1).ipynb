# %% [markdown]
# ## Картинка 1

# %%
import neuro_lib    # Импорт своей библиотеки для работы с Neuro обработкой файлов

file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_1\2020-12_11_13-15-23.txt"

param_str = [3.3, 68000] # Параметры структуры: V(В) пит., R(Ом) доп.

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')

import numpy as np
import pandas as pd

data = pd.read_csv(file, header=None, sep = "\t")
#print (data, '\n')
print (param_str)
# Out:
# [3.3, 68000]

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок

x = data[0]/1000
y = 1/((param_str[0] - data[1])*param_str[1]/[1])

fig, ax = plt.subplots()
ax.set_facecolor('w') # установка фона графика

ax.plot(x, y, linewidth = 0.5, label="20 sec - 2.4 V", color='r')
ax.legend()
ax.set_xlabel("Time (sec)")
ax.set_ylabel("Conductivity (S)")
plt.title("Time dependence")
ax.set_xlim(-100, 15000)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок

fig, ax = plt.subplots()

ax.plot(x, y, linewidth = 0.5, label="20 sec - 2.4 V", color='r')
ax.legend()
ax.set_xlabel("Time (sec)")
ax.set_ylabel("Conductivity (S)")
plt.title("Time dependence")
ax.set_xlim(2000, 8000)
ax.set_ylim(0.000014, 0.000022)
plt.show()

# %%
import neuro_lib_2
res_1 = neuro_lib_2.on_off_impulse(file)
print (res_1.head().to_string())

x = res_1['N'].drop(1)
y_on = res_1['on_end_t'].drop(1) - res_1['on_start_t'].drop(1)
y_off = res_1['off_end_t'].drop(1) - res_1['off_start_t'].drop(1)

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок

fig, ax1 = plt.subplots()
ax1.set_facecolor('w') # установка фона графика
ax2 = ax1.twinx() # позволяет вывести 2 графика на 1

curve1 = ax1.scatter(x, y_on, s=6, label="on", color='r')
curve2 = ax2.scatter(x, y_off, s=6, label="off", color='b')
curves = [curve1, curve2]
#ax1.legend(curves, [curve.get_label() for curve in curves], facecolor="yellow") # ??? отображение легенды

ax1.set_xlabel("Pulse number (N)")
ax1.set_ylabel("Delay_on t (sec)", color = 'red')
ax2.set_ylabel("Delay_off t (sec)", color = 'blue')
plt.title("Duration on / off from pulse number")
#ax1.axis([0, 50, 0, 15])

plt.grid(False) # отключение сетки
plt.show()
# Out:
#    N on_start_t on_start_V on_end_t on_end_V off_start_t off_start_V off_end_t off_end_V
# 0  0        NaN        NaN      NaN      NaN         NaN         NaN    10.008  0.086125
# 1  1     11.025   0.124625  1811.15  2.76425     1811.65     2.75738   2510.23    2.3995
# 2  2    2510.75    2.42725  2530.75  2.54675     2530.81     2.53762   2739.55    2.3995
# 3  3    2739.62      2.438  2759.62  2.53512     2759.68       2.524   2931.37   2.39913
# 4  4    2931.44    2.42588  2951.46  2.52738     2951.51     2.51638   3104.78   2.39975

# %% [markdown]
# ## Картинка 2

# %%
import neuro_lib    # Импорт своей библиотеки для работы с Neuro обработкой файлов

file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_1\2020-12_12_16-34-45.txt"

param_str = [3.3, 68000] # Параметры структуры: V(В) пит., R(Ом) доп.

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')

import numpy as np
import pandas as pd

data = pd.read_csv(file, header=None, sep = "\t")
#print (data, '\n')
print (param_str)
# Out:
# [3.3, 68000]

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок

x = data[0]/1000
y = 1/((param_str[0] - data[1])*param_str[1]/[1])

fig, ax = plt.subplots()
ax.set_facecolor('w') # установка фона графика

ax.plot(x, y, linewidth = 0.5, label="40 sec - 2 V", color='r')
ax.legend()
ax.set_xlabel("Time (sec)")
ax.set_ylabel("Conductivity (S)")
plt.title("Time dependence")
ax.set_xlim(-100, 70000)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 5)  # Размер картинок

fig, ax = plt.subplots()

ax.plot(x, y, linewidth = 0.5, label="40 sec - 2 V", color='r')
ax.legend()
ax.set_xlabel("Time (sec)")
ax.set_ylabel("Conductivity (S)")
plt.title("Time dependence")
ax.set_xlim(2000, 45000)
ax.set_ylim(0.000010, 0.000018)
plt.show()

# %%
import neuro_lib_2
res_1 = neuro_lib_2.on_off_impulse(file)
print (res_1.head().to_string())

x = res_1['N'].drop(1)
y_on = res_1['on_end_t'].drop(1) - res_1['on_start_t'].drop(1)
y_off = res_1['off_end_t'].drop(1) - res_1['off_start_t'].drop(1)

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (10, 5)  # Размер картинок

fig, ax1 = plt.subplots()
ax1.set_facecolor('w') # установка фона графика
ax2 = ax1.twinx() # позволяет вывести 2 графика на 1

curve1 = ax1.scatter(x, y_on, s=6, label="on", color='r')
curve2 = ax2.scatter(x, y_off, s=6, label="off", color='b')
curves = [curve1, curve2]
#ax1.legend(curves, [curve.get_label() for curve in curves], facecolor="yellow") # ??? отображение легенды

ax1.set_xlabel("Pulse number (N)")
ax1.set_ylabel("Delay_on t (sec)", color = 'red')
ax2.set_ylabel("Delay_off t (sec)", color = 'blue')
plt.title("Duration on / off from pulse number")
#ax1.axis([0, 50, 0, 15])

plt.grid(False) # отключение сетки
plt.show()
# Out:
#    N on_start_t on_start_V on_end_t on_end_V off_start_t off_start_V off_end_t off_end_V
# 0  0        NaN        NaN      NaN      NaN         NaN         NaN    10.007  0.240375
# 1  1     11.023   0.300125  1811.05  2.76675     1811.55       2.761   4966.72   1.99975
# 2  2    4967.23    2.05375  5007.27  2.36413     5007.33     2.35113   6381.54   1.99988
# 3  3    6381.61    2.05238  6421.61  2.34212     6421.66     2.33062   7653.75   1.99962
# 4  4    7653.82    2.04325  7693.84  2.33412      7693.9     2.32187   8854.74   1.99988
