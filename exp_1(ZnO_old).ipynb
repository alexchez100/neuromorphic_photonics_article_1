# %%
import neuro_lib    # Импорт своей библиотеки для работы с Neuro обработкой файлов

file = r"C:\Users\alexc\Desktop\Data_boss\Data_ZnO_old\2020-11_20_21-23-17.txt"

param_str = [3.3, 68000] # Параметры структуры: V(В) пит., R(Ом) доп.

neuro_lib.replace (file)
neuro_lib.replace (file, '         ', '\t')
print (param_str)
# Out:
# [3.3, 68000]

# %%
import numpy as np
import pandas as pd

data = pd.read_csv(file, header=None, sep = "\t")
print (data, '\n')
#print (data[0], '\n')
# Out:
#                0         1
# 0              6  0.012625
# 1           1007  0.012625
# 2           2008  0.012625
# 3           3008  0.012250
# 4           4009  0.012625
# ...          ...       ...
# 107928  50498320  0.035000
# 107929  50499320  0.035500
# 107930  50500320  0.035375
# 107931  50501321  0.035625
# 107932  50502321  0.035250
#
# [107933 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (16, 9)  # Размер картинок

x = data[0]/1000
y = data[1]

fig, ax = plt.subplots()
ax.set_facecolor('w') # установка фона графика

ax.plot(x, y, linewidth = 0.5, label="ZnO_850", color='r')
ax.legend()
ax.set_xlabel("Time (sec)")
ax.set_ylabel("Signal (V)")
#plt.title("Time dependence")
#ax.axis([0, 10, 1.2, 1.6])

######################## 2 график ##########################
plt.rcParams['figure.figsize'] = (16, 9)  # Размер картинок

x = data[0]/1000
y = 1/((param_str[0] - data[1])*param_str[1]/data[1])

fig, ax = plt.subplots()
ax.set_facecolor('w') # установка фона графика

ax.plot(x, y, linewidth = 0.5, label="ZnO_850", color='r')
ax.legend()
ax.set_xlabel("Time (sec)")
ax.set_ylabel("Conductivity (S)")
#plt.title("Time dependence")
#ax.axis([0, 10, 1.2, 1.6])
plt.show()

######################## 3 график ##########################
# plt.rcParams['figure.figsize'] = (16, 9)  # Размер картинок

# x = data[0]/1000
# y = data[1]/param_str[1]

# fig, ax = plt.subplots()
# ax.set_facecolor('w') # установка фона графика

# ax.plot(x, y, linewidth = 0.5, label="ZnO_1", color='r')
# ax.legend()
# ax.set_xlabel("Time (sec)")
# ax.set_ylabel("Current (A)")
# #plt.title("Time dependence")
# #ax.axis([0, 10, 1.2, 1.6])
# plt.show()

# %%
# Перевод из V -> S
v_1 = 1.2
v_2 = 1.4
print("s_1 = ", v_1/(param_str[0]-v_1)/param_str[1], "s_2 = ", v_2/(param_str[0]-v_2)/param_str[1])
# Out:
# s_1 =  8.403361344537817e-06 s_2 =  1.0835913312693498e-05

# %%
# Перевод из S -> V
param_str = [3.3, 68000]
s_1 = 0.0000105
s_2 = 0.0000120
print("v_1 = ", round(s_1*param_str[0]*param_str[1]/(1+s_1*param_str[1]), 4), "v_2 = ", round(s_2*param_str[0]*param_str[1]/(1+s_2*param_str[1]), 4))
# Out:
# v_1 =  1.3747 v_2 =  1.4828
